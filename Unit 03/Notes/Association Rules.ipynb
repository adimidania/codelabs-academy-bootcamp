# %% [markdown]
# # Apriori Algorithm

# %%
import random
import numpy as np
import string
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules, fpgrowth
from mlxtend.preprocessing import TransactionEncoder

# %%
results = [['Milk', 'Onion', 'Nuts', 'Eggs', 'Ice cream', 'Yogurt'], 
          ['Dill', 'Onion', 'Nuts', 'Eggs', 'Ice cream', 'Yogurt'],
          ['Milk', 'Apple', 'Eggs', 'Ice cream'],
          ['Milk', 'Unicorn', 'Corn', 'Ice cream', 'Yogurt'],
          ['Corn', 'Onion', 'Onion', 'Ice cream', 'Eggs', 'Cake']]
results
# Out:
# [['Milk', 'Onion', 'Nuts', 'Eggs', 'Ice cream', 'Yogurt'],
#  ['Dill', 'Onion', 'Nuts', 'Eggs', 'Ice cream', 'Yogurt'],
#  ['Milk', 'Apple', 'Eggs', 'Ice cream'],
#  ['Milk', 'Unicorn', 'Corn', 'Ice cream', 'Yogurt'],
#  ['Corn', 'Onion', 'Onion', 'Ice cream', 'Eggs', 'Cake']]

# %%
TE = TransactionEncoder()
res = TE.fit(results).transform(results)

# %%
df = pd.DataFrame(res, columns=TE.columns_)
df
# Out:
#    Apple   Cake   Corn   Dill   Eggs  Ice cream   Milk   Nuts  Onion  Unicorn  \
# 0  False  False  False  False   True       True   True   True   True    False
# 1  False  False  False   True   True       True  False   True   True    False
# 2   True  False  False  False   True       True   True  False  False    False
# 3  False  False   True  False  False       True   True  False  False     True
# 4  False   True   True  False   True       True  False  False   True    False
#
#    Yogurt
# 0    True
# 1    True
# 2   False
# 3    True
# 4   False

# %%
# Let's first extract the items that appear together (or alone) with a minimal support of 60%
frequent_items = apriori(df, min_support=0.6, use_colnames=True)
frequent_items
# Out:
#     support                  itemsets
# 0       0.8                    (Eggs)
# 1       1.0               (Ice cream)
# 2       0.6                    (Milk)
# 3       0.6                   (Onion)
# 4       0.6                  (Yogurt)
# 5       0.8         (Ice cream, Eggs)
# 6       0.6             (Onion, Eggs)
# 7       0.6         (Ice cream, Milk)
# 8       0.6        (Onion, Ice cream)
# 9       0.6       (Ice cream, Yogurt)
# 10      0.6  (Onion, Ice cream, Eggs)

# %%
# Displaying a metric to better understand what's going on with these items that are appearing together
result = association_rules(frequent_items, metric="confidence", min_threshold=0.7)
result
# Out:
#            antecedents         consequents  antecedent support  \
# 0          (Ice cream)              (Eggs)                 1.0
# 1               (Eggs)         (Ice cream)                 0.8
# 2              (Onion)              (Eggs)                 0.6
# 3               (Eggs)             (Onion)                 0.8
# 4               (Milk)         (Ice cream)                 0.6
# 5              (Onion)         (Ice cream)                 0.6
# 6             (Yogurt)         (Ice cream)                 0.6
# 7   (Onion, Ice cream)              (Eggs)                 0.6
# 8        (Onion, Eggs)         (Ice cream)                 0.6
# 9    (Eggs, Ice cream)             (Onion)                 0.8
# 10             (Onion)   (Eggs, Ice cream)                 0.6
# 11              (Eggs)  (Onion, Ice cream)                 0.8
#
#     consequent support  support  confidence  lift  leverage  conviction
# 0                  0.8      0.8        0.80  1.00      0.00         1.0
# 1                  1.0      0.8        1.00  1.00      0.00         inf
# 2                  0.8      0.6        1.00  1.25      0.12         inf
# 3                  0.6      0.6        0.75  1.25      0.12         1.6
# 4                  1.0      0.6        1.00  1.00      0.00         inf
# 5                  1.0      0.6        1.00  1.00      0.00         inf
# 6                  1.0      0.6        1.00  1.00      0.00         inf
# 7                  0.8      0.6        1.00  1.25      0.12         inf
# 8                  1.0      0.6        1.00  1.00      0.00         inf
# 9                  0.6      0.6        0.75  1.25      0.12         1.6
# 10                 0.8      0.6        1.00  1.25      0.12         inf
# 11                 0.6      0.6        0.75  1.25      0.12         1.6

# %%
new_result = result[['antecedents', 'consequents', 'support', 'confidence', 'lift']]
new_result
# Out:
#            antecedents         consequents  support  confidence  lift
# 0          (Ice cream)              (Eggs)      0.8        0.80  1.00
# 1               (Eggs)         (Ice cream)      0.8        1.00  1.00
# 2              (Onion)              (Eggs)      0.6        1.00  1.25
# 3               (Eggs)             (Onion)      0.6        0.75  1.25
# 4               (Milk)         (Ice cream)      0.6        1.00  1.00
# 5              (Onion)         (Ice cream)      0.6        1.00  1.00
# 6             (Yogurt)         (Ice cream)      0.6        1.00  1.00
# 7   (Onion, Ice cream)              (Eggs)      0.6        1.00  1.25
# 8        (Onion, Eggs)         (Ice cream)      0.6        1.00  1.00
# 9    (Eggs, Ice cream)             (Onion)      0.6        0.75  1.25
# 10             (Onion)   (Eggs, Ice cream)      0.6        1.00  1.25
# 11              (Eggs)  (Onion, Ice cream)      0.6        0.75  1.25

# %%
brand_new_result = new_result[new_result['confidence']>=1]
brand_new_result
# Out:
#            antecedents        consequents  support  confidence  lift
# 1               (Eggs)        (Ice cream)      0.8         1.0  1.00
# 2              (Onion)             (Eggs)      0.6         1.0  1.25
# 4               (Milk)        (Ice cream)      0.6         1.0  1.00
# 5              (Onion)        (Ice cream)      0.6         1.0  1.00
# 6             (Yogurt)        (Ice cream)      0.6         1.0  1.00
# 7   (Onion, Ice cream)             (Eggs)      0.6         1.0  1.25
# 8        (Onion, Eggs)        (Ice cream)      0.6         1.0  1.00
# 10             (Onion)  (Eggs, Ice cream)      0.6         1.0  1.25

# %% [markdown]
# # FP Growth Algorithm

# %%
# Fp growth are faster
fp_growth = fpgrowth(df, min_support = 0.6, use_colnames=True)
fp_growth
# Out:
#     support                  itemsets
# 0       1.0               (Ice cream)
# 1       0.8                    (Eggs)
# 2       0.6                  (Yogurt)
# 3       0.6                   (Onion)
# 4       0.6                    (Milk)
# 5       0.8         (Ice cream, Eggs)
# 6       0.6       (Ice cream, Yogurt)
# 7       0.6             (Onion, Eggs)
# 8       0.6        (Onion, Ice cream)
# 9       0.6  (Onion, Ice cream, Eggs)
# 10      0.6         (Ice cream, Milk)
